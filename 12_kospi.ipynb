# %% [markdown]
# STEP 10 — 캔들스틱 차트 (go.Candlestick)

# %% [markdown]
# go.Candlestick(
#     x=df.index,       # x축: 날짜
#     open=df['Open'],  # 시가
#     high=df['High'],  # 고가
#     low=df['Low'],    # 저가
#     close=df['Close'] # 종가
# )

# %% [markdown]
# df_stock.index[-1] --> 가장 최근 날짜

# %% [markdown]
# ## pd.DateOffset(monts=3) --> 달력 기준 3개월
# - datetime.timedelta(days=90)과 비슷하다.
# - 월말 처리 부분이 더 정확하다!

# %% [markdown]
# # 최근 3개월만 표시
# three_monts_ago = df_stock.index[-1] - pd.DateOffset(months=3)
# # 결과 데이터프레임
# df_candle = df_stock[df_stock.index >= three_months_ago]

# %% [markdown]
# # 결과 차트 정보 저장하기 전에 데이터확인
# df_candle.tail()

# %% [markdown]
# # 캔들 차트
# fig_candle = go.Figure(data=[go.Candlestick(
#     x=df.index,       # x축: 날짜
#     open=df['Open'],  # 시가
#     high=df['High'],  # 고가
#     low=df['Low'],    # 저가
#     close=df['Close'] # 종가
# )])
#
# # 캔들 차트 - 디자인
# fig_candle.update_layout(
#     title=f'{target_name} 캔들스틱 차트 (최근 3개월)',
#     xaxis_title='날짜',
#     yaxis_title='가격 (원)',
#     xaxis_rangeslider_visible=False,   # 하단 범위 슬라이더 숨김
#     height=500
# )
#
# fig_candle.show()
